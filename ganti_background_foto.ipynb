# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
image = cv2.imread('atta.jpeg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print(f"This image's dimension: {image.shape}")
plt.imshow(image)
plt.style.use('default')
# Out:
# This image's dimension: (327, 581, 3)

# %%
image_copy = np.copy(image)
plt.imshow(image_copy)

# %%
# define the color threshold

lower_blue = np.array([0,0,200])
upper_blue = np.array([100,100,255])

# %%
# create a mask, select area of interest

mask = cv2.inRange(image_copy, lower_blue, upper_blue)
plt.imshow(mask, cmap = 'gray')

# %%
# mask the image to let the object show through

masked_image = np.copy(image_copy)
masked_image[mask != 0] = [0,0,0]
plt.imshow(masked_image)

# %%
# mask and add a background image

background_image = cv2.imread('red.jpg')
background_image = cv2.cvtColor(background_image, cv2.COLOR_BGR2RGB)

crop_background = background_image[0:327, 0:581]
crop_background[mask == 0] = [0,0,0]
plt.imshow(crop_background)

# %%
# create a complete image

complete_image = masked_image + crop_background

plt.imshow(complete_image)
